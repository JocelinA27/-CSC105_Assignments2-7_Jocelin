# %%
import pandas as pd

# %%
df = pd.read_csv('Data/job_postings.csv')

# %%
df
# Out:
#            job_id  company_id                                  title  \
# 0        85008768         NaN               Licensed Insurance Agent
# 1       133114754  77766802.0                          Sales Manager
# 2       133196985   1089558.0                     Model Risk Auditor
# 3       381055942  96654609.0                       Business Manager
# 4       529257371   1244539.0                    NY Studio Assistant
# ...           ...         ...                                    ...
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                              description  max_salary  \
# ...

# %%
df.columns
# Out:
# Index(['job_id', 'company_id', 'title', 'description', 'max_salary',
#        'med_salary', 'min_salary', 'pay_period', 'formatted_work_type',
#        'location', 'applies', 'original_listed_time', 'remote_allowed',
#        'views', 'job_posting_url', 'application_url', 'application_type',
#        'expiry', 'closed_time', 'formatted_experience_level', 'skills_desc',
#        'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type'],
#       dtype='object')

# %%
df[['title', 'min_salary', 'location']]
# Out:
#                                        title  min_salary           location
# 0                   Licensed Insurance Agent     45760.0          Chico, CA
# 1                              Sales Manager         NaN  Santa Clarita, CA
# 2                         Model Risk Auditor         NaN       New York, NY
# 3                           Business Manager         NaN         Forney, TX
# 4                        NY Studio Assistant         NaN       New York, NY
# ...                                      ...         ...                ...
# 15881                  Sanitation Technician         NaN  West Columbia, SC
# 15882                         Unit Secretary         NaN        Teaneck, NJ
# 15883                Radiology Aide, Perdiem         NaN        Teaneck, NJ
# 15884                            MRI Manager    110000.0       New York, NY
# 15885  Area Director of Business Development         NaN      Vicksburg, MS
#
# [15886 rows x 3 columns]

# %%
df2 = df[['title', 'min_salary', 'location']]

# %%
df[df['title'] == "Sales Associate"]
# Out:
#            job_id  company_id            title  \
# 641    3693044422      4122.0  Sales Associate
# 1876   3693049883    612636.0  Sales Associate
# 1877   3693049884    612636.0  Sales Associate
# 2310   3693051793     12007.0  Sales Associate
# 4048   3693071274     38264.0  Sales Associate
# ...           ...         ...              ...
# 15249  3701359420      6734.0  Sales Associate
# 15294  3701361398     30755.0  Sales Associate
# 15317  3701362458     30755.0  Sales Associate
# 15320  3701362506     30755.0  Sales Associate
# 15343  3701363168      6734.0  Sales Associate
#
#                                              description  max_salary  \
# 641    About the Role As a Sales Associate you provid...         NaN
# 1876   Job Description\nThe Sales Associate is respon...         NaN
# 1877   Job Description\nThe Sales Associate is respon...         NaN
# 2310   At Montblanc Americas, We are proud to employ ...         NaN
# ...

# %%
df3 = df[df['title'] == "Sales Associate"]

# %%
df3
# Out:
#            job_id  company_id            title  \
# 641    3693044422      4122.0  Sales Associate
# 1876   3693049883    612636.0  Sales Associate
# 1877   3693049884    612636.0  Sales Associate
# 2310   3693051793     12007.0  Sales Associate
# 4048   3693071274     38264.0  Sales Associate
# ...           ...         ...              ...
# 15249  3701359420      6734.0  Sales Associate
# 15294  3701361398     30755.0  Sales Associate
# 15317  3701362458     30755.0  Sales Associate
# 15320  3701362506     30755.0  Sales Associate
# 15343  3701363168      6734.0  Sales Associate
#
#                                              description  max_salary  \
# 641    About the Role As a Sales Associate you provid...         NaN
# 1876   Job Description\nThe Sales Associate is respon...         NaN
# 1877   Job Description\nThe Sales Associate is respon...         NaN
# 2310   At Montblanc Americas, We are proud to employ ...         NaN
# ...

# %%
df2
# Out:
#                                        title  min_salary           location
# 0                   Licensed Insurance Agent     45760.0          Chico, CA
# 1                              Sales Manager         NaN  Santa Clarita, CA
# 2                         Model Risk Auditor         NaN       New York, NY
# 3                           Business Manager         NaN         Forney, TX
# 4                        NY Studio Assistant         NaN       New York, NY
# ...                                      ...         ...                ...
# 15881                  Sanitation Technician         NaN  West Columbia, SC
# 15882                         Unit Secretary         NaN        Teaneck, NJ
# 15883                Radiology Aide, Perdiem         NaN        Teaneck, NJ
# 15884                            MRI Manager    110000.0       New York, NY
# 15885  Area Director of Business Development         NaN      Vicksburg, MS
#
# [15886 rows x 3 columns]

# %% [markdown]
# ### **98.42%**

# %%
df2.dropna()
# Out:
#                                                    title  min_salary  \
# 0                               Licensed Insurance Agent    45760.00
# 5                                       Office Associate    37000.00
# 8                       Registered Nurse (RN) Vaccinator       50.00
# 12                              Administrative Assistant       18.00
# 13     REMOTE STEEL BUILDING SALES MAKE $1,000 TO $30...    12000.00
# ...                                                  ...         ...
# 15870                                     Senior Analyst    75000.00
# 15871                                      Sales Manager    60000.00
# 15875                                      Design Intern       19.08
# 15878         Sr. Bilingual Copywriter (Canadian French)    91900.00
# 15884                                        MRI Manager   110000.00
#
#                    location
# 0                 Chico, CA
# 5                Albany, GA
# 8              Muskegon, MI
# ...

# %%
df2.dropna().drop(df2[df2['min_salary'] <= 20000].index)
# Out:
#                                             title  min_salary  \
# 0                        Licensed Insurance Agent     45760.0
# 5                                Office Associate     37000.0
# 23                   Manager, Salesforce Platform     98640.0
# 27                     Mental Health Professional     55280.0
# 28                     Mental Health Professional     55280.0
# ...                                           ...         ...
# 15864                  Insurance Defense Attorney     70800.0
# 15870                              Senior Analyst     75000.0
# 15871                               Sales Manager     60000.0
# 15878  Sr. Bilingual Copywriter (Canadian French)     91900.0
# 15884                                 MRI Manager    110000.0
#
#                            location
# 0                         Chico, CA
# 5                        Albany, GA
# 23     New Hampshire, United States
# 27                      Spokane, WA
# ...

# %%
df4 = df2.dropna().drop(df2[df2['min_salary'] <= 20000].index)

# %%
df[(df['title'] == "Sales Associate") & (df['min_salary']) & (df['location'] == "Raleigh, NC")]
# Out:
#            job_id  company_id            title  \
# 11151  3699086928   5061336.0  Sales Associate
#
#                                              description  max_salary  \
# 11151  BUILD YOUR FUTURE WHILE YOU HELP BUILD A BETTE...     65000.0
#
#        med_salary  min_salary pay_period formatted_work_type     location  \
# 11151         NaN     50000.0     YEARLY           Full-time  Raleigh, NC
#
#        ...         expiry  closed_time  formatted_experience_level  \
# 11151  ...  1695426954000          NaN                   Associate
#
#        skills_desc    listed_time posting_domain sponsored  work_type  \
# 11151          NaN  1692834955000            NaN         1  FULL_TIME
#
#        currency compensation_type
# 11151       USD       BASE_SALARY
#
# [1 rows x 27 columns]
