# %%
import pandas as pd

# %%
df = pd.read_csv("Data/Motor_Vehicle_Collisions_-_Crashes 2.csv")

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN       NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN       NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN       NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN   11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN   11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df.shape
# Out:
# (1104708, 29)

# %%
df.head(2)
# Out:
#    CRASH DATE CRASH TIME BOROUGH  ZIP CODE  LATITUDE  LONGITUDE LOCATION  \
# 0  09/11/2021       2:39     NaN       NaN       NaN        NaN      NaN
# 1  03/26/2022      11:45     NaN       NaN       NaN        NaN      NaN
#
#             ON STREET NAME CROSS STREET NAME OFF STREET NAME  ...  \
# 0    WHITESTONE EXPRESSWAY         20 AVENUE             NaN  ...
# 1  QUEENSBORO BRIDGE UPPER               NaN             NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                    Unspecified                            NaN
# 1                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN     4455765.0
# 1                            NaN                            NaN     4513547.0
#
#    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# ...

# %%
df.tail(2)
# Out:
#          CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 1104706  05/27/2016      19:00     NaN       NaN  40.705887 -73.942970
# 1104707  06/02/2016       4:30   BRONX   10474.0  40.816864 -73.882744
#
#                         LOCATION                    ON STREET NAME  \
# 1104706   (40.705887, -73.94297)  BOERUM STREET
# 1104707  (40.816864, -73.882744)                               NaN
#
#         CROSS STREET NAME                           OFF STREET NAME  ...  \
# 1104706               NaN                                       NaN  ...
# 1104707               NaN  772       EDGEWATER ROAD                  ...
#
#          CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 1104706                    Unspecified                            NaN
# 1104707                        Unspeci                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# ...

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df['LONGITUDE'].describe()
# Out:
# count    1.022581e+06
# mean    -7.367413e+01
# std      4.531354e+00
# min     -2.013600e+02
# 25%     -7.397096e+01
# 50%     -7.392285e+01
# 75%     -7.386370e+01
# max      0.000000e+00
# Name: LONGITUDE, dtype: float64

# %%
df['LONGITUDE'].mean()
# Out:
# -73.67413371835774

# %%
df['LONGITUDE'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['LONGITUDE'].sum()
#
# NameError: name 'df' is not defined
